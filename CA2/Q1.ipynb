# %%
import random

# %%
class BankAccount:
    def __init__(self, account_number, initial_balance):
        self.account_number = account_number
        self.balance = initial_balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount

    def get_balance(self):
        return self.balance

# %%
def generate_accounts(num_accounts, num_months, num_transactions, seed_value):
    random.seed(seed_value) 
    accounts = []
    
    for i in range(1, num_accounts + 1):
        initial_balance = random.randint(1000, 10000)  
        account = BankAccount(account_number=i, initial_balance=initial_balance)
        
        
        for _ in range(num_months):
            for _ in range(num_transactions):
                if random.choice([True, False]):  
                    account.deposit(random.randint(100, 1000))  
                else:
                    account.withdraw(random.randint(100, 1000))  
        
        accounts.append(account)
    
    
    sorted_accounts = sorted(accounts, key=lambda x: x.get_balance())
    
    return sorted_accounts

# %%
num_accounts = 100
num_months = 6  
num_transactions = 10  
seed_value = 42 

accounts = generate_accounts(num_accounts, num_months, num_transactions, seed_value)

for account in accounts:
    print(f"Account {account.account_number}: Balance = ₹{account.get_balance()}")
# Out:
# Account 19: Balance = ₹277
# Account 72: Balance = ₹376
# Account 56: Balance = ₹460
# Account 74: Balance = ₹574
# Account 30: Balance = ₹797
# Account 18: Balance = ₹807
# Account 33: Balance = ₹839
# Account 10: Balance = ₹927
# Account 46: Balance = ₹1047
# Account 54: Balance = ₹1203
# Account 20: Balance = ₹1216
# Account 55: Balance = ₹1272
# Account 47: Balance = ₹1287
# Account 14: Balance = ₹1409
# Account 5: Balance = ₹1761
# Account 96: Balance = ₹1873
# Account 100: Balance = ₹1904
# Account 86: Balance = ₹2012
# Account 25: Balance = ₹2141
# Account 88: Balance = ₹2256
# Account 84: Balance = ₹2293
# Account 48: Balance = ₹2300
# Account 45: Balance = ₹2504
# Account 70: Balance = ₹3045
# Account 22: Balance = ₹3091
# Account 76: Balance = ₹3228
# Account 85: Balance = ₹3297
# Account 39: Balance = ₹3376
# Account 89: Balance = ₹3866
# Account 69: Balance = ₹4016
# Account 67: Balance = ₹4345
# Account 12: Balance = ₹4493
# Account 57: Balance = ₹4594
# ...
